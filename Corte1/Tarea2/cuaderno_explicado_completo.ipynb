# %% [markdown]
# # Guía Completa de Diccionarios en Python
# Explicación exhaustiva línea por línea de todo el código proporcionado (incluyendo comentarios y líneas vacías) en formato .ipynb estricto.

# %% [markdown]
# ### Línea 1
# **Código:** `# sensors =  {"living room": 21, "kitchen": 23, "bedroom": 20, "pantry": 22}`
#
# **Explicación técnica:** Declara de forma comentada un diccionario 'sensors' con nombres de habitaciones como claves y temperaturas como valores. Representa la creación inicial de un diccionario de lecturas.

# %%
# sensors =  {"living room": 21, "kitchen": 23, "bedroom": 20, "pantry": 22}

# %% [markdown]
# ### Línea 2
# **Código:** `# num_cameras = {"backyard": 6,  "garage": 2, "driveway": 1}`
#
# **Explicación técnica:** Declara de forma comentada un diccionario 'num_cameras' con ubicaciones y cantidad de dispositivos. Ilustra el almacenamiento de conteos asociados a ubicaciones.

# %%
# num_cameras = {"backyard": 6,  "garage": 2, "driveway": 1}

# %% [markdown]
# ### Línea 3
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa visualmente las declaraciones de variables de las instrucciones de impresión.

# %% [markdown]
# ### Línea 4
# **Código:** `# print(sensors)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el diccionario 'sensors'. Servía para verificar en consola el contenido del primer diccionario.

# %%
# print(sensors)

# %% [markdown]
# ### Línea 5
# **Código:** `# print(num_cameras)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el diccionario 'num_cameras'. Servía para comprobar las cámaras registradas.

# %%
# print(num_cameras)

# %% [markdown]
# ### Línea 6
# **Código:** `# translations = {"mountain": "orod", "bread": "bass", "friend": "mellon", "horse": "roch" }`
#
# **Explicación técnica:** Declara de forma comentada un diccionario 'translations' de inglés a élfico. Muestra el uso de diccionarios como mapeos o traductores de cadenas de texto.

# %%
# translations = {"mountain": "orod", "bread": "bass", "friend": "mellon", "horse": "roch" }

# %% [markdown]
# ### Línea 7
# **Código:** `# print(translations)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el diccionario 'translations'. Servía para visualizar la estructura de traducción creada.

# %%
# print(translations)

# %% [markdown]
# ### Línea 8
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el bloque de creación básica del bloque de verificación de errores.

# %% [markdown]
# ### Línea 9
# **Código:** `##Verifiying an error:`
#
# **Explicación técnica:** Comentario de encabezado. Indica el inicio de una prueba para demostrar un error común en la definición de claves.

# %%
##Verifiying an error:

# %% [markdown]
# ### Línea 10
# **Código:** `# powers = {[1, 2, 4, 8, 16]: 2, [1, 3, 9, 27, 81]: 3}`
#
# **Explicación técnica:** Intento comentado de usar listas mutables como claves de un diccionario. Ejemplifica que las claves deben ser tipos inmutables (hashables) provocando un TypeError.

# %%
# powers = {[1, 2, 4, 8, 16]: 2, [1, 3, 9, 27, 81]: 3}

# %% [markdown]
# ### Línea 11
# **Código:** `# # print(powers)`
#
# **Explicación técnica:** Línea con doble comentario para imprimir 'powers'. Permanece desactivada debido al error de sintaxis/tipo de la línea anterior.

# %%
# # print(powers)

# %% [markdown]
# ### Línea 12
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la demostración de error del siguiente ejemplo con listas como valores.

# %% [markdown]
# ### Línea 13
# **Código:** `# children = {"von Trapp": ["Johannes", "Rosmarie", "Eleonore"] , "Corleone": ["Sonny", "Fredo", "Michael"]}`
#
# **Explicación técnica:** Declara de forma comentada un diccionario 'children' con listas como valores. Demuestra que aunque las claves deben ser inmutables, los valores sí pueden ser colecciones mutables.

# %%
# children = {"von Trapp": ["Johannes", "Rosmarie", "Eleonore"] , "Corleone": ["Sonny", "Fredo", "Michael"]}

# %% [markdown]
# ### Línea 14
# **Código:** `# print(children)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el diccionario 'children'. Muestra la estructura de claves asociadas a listas de elementos.

# %%
# print(children)

# %% [markdown]
# ### Línea 15
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la sección previa de la declaración de diccionarios vacíos.

# %% [markdown]
# ### Línea 16
# **Código:** `# my_empty_dictionary = {}`
#
# **Explicación técnica:** Declara de forma comentada un diccionario vacío 'my_empty_dictionary' usando {}. Define la sintaxis base para inicializar diccionarios que se poblarán dinámicamente.

# %%
# my_empty_dictionary = {}

# %% [markdown]
# ### Línea 17
# **Código:** `# print(my_empty_dictionary)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el diccionario vacío. Muestra en consola la representación visual '{}'.

# %%
# print(my_empty_dictionary)

# %% [markdown]
# ### Línea 18
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la inicialización vacía del bloque de inserción de elementos.

# %% [markdown]
# ### Línea 19
# **Código:** `# menu = {"oatmeal": 3, "avocado toast": 6, "carrot juice": 5, "blueberry muffin": 2}`
#
# **Explicación técnica:** Declara de forma comentada un diccionario 'menu' con platillos y precios. Establece la estructura de datos base para probar inserciones.

# %%
# menu = {"oatmeal": 3, "avocado toast": 6, "carrot juice": 5, "blueberry muffin": 2}

# %% [markdown]
# ### Línea 20
# **Código:** `# print("Before: ", menu)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el menú antes de modificarlo. Servía para comparar el estado inicial con el posterior.

# %%
# print("Before: ", menu)

# %% [markdown]
# ### Línea 21
# **Código:** `# menu["cheesecake"] = 8`
#
# **Explicación técnica:** Asignación comentada que agrega la clave 'cheesecake' con valor 8. Muestra la sintaxis directa mediante corchetes para insertar un nuevo par clave-valor.

# %%
# menu["cheesecake"] = 8

# %% [markdown]
# ### Línea 22
# **Código:** `# print("After", menu)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el menú tras la inserción. Verificaba la adición del nuevo elemento.

# %%
# print("After", menu)

# %% [markdown]
# ### Línea 23
# **Código:** `# animals_in_zoo = {"dinosaurs": 0}`
#
# **Explicación técnica:** Declara de forma comentada el diccionario 'animals_in_zoo' con 'dinosaurs' en 0. Define el punto de partida para probar reasignaciones.

# %%
# animals_in_zoo = {"dinosaurs": 0}

# %% [markdown]
# ### Línea 24
# **Código:** `# animals_in_zoo = {"dinosaurs": 0}`
#
# **Explicación técnica:** Reasigna de forma comentada exactamente la misma estructura. Muestra cómo la reasignación de la variable reemplaza por completo el objeto anterior.

# %%
# animals_in_zoo = {"dinosaurs": 0}

# %% [markdown]
# ### Línea 25
# **Código:** `# animals_in_zoo = {"horses": 2}`
#
# **Explicación técnica:** Reasigna de forma comentada el diccionario con una nueva clave 'horses'. Reemplaza la clave anterior demostrando la sobreescritura total de la variable.

# %%
# animals_in_zoo = {"horses": 2}

# %% [markdown]
# ### Línea 26
# **Código:** `# print(animals_in_zoo)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el estado final de 'animals_in_zoo'. Confirmaba el contenido tras las reasignaciones.

# %%
# print(animals_in_zoo)

# %% [markdown]
# ### Línea 27
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el bloque previo de la sección de actualización múltiple.

# %% [markdown]
# ### Línea 28
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Espaciado estructural adicional.

# %% [markdown]
# ### Línea 29
# **Código:** `##Add multiple keys`
#
# **Explicación técnica:** Comentario de sección. Introduce el tema de inserción masiva de múltiples claves a la vez.

# %%
##Add multiple keys

# %% [markdown]
# ### Línea 30
# **Código:** `# sensors = {"living room": 21, "kitchen": 23, "bedroom": 20}`
#
# **Explicación técnica:** Declara de forma comentada el diccionario 'sensors' con tres habitaciones. Prepara la estructura base para aplicar el método update.

# %%
# sensors = {"living room": 21, "kitchen": 23, "bedroom": 20}

# %% [markdown]
# ### Línea 31
# **Código:** `# print("Before", sensors)`
#
# **Explicación técnica:** Instrucción comentada para imprimir 'sensors' antes de actualizarlo. Permite contrastar la cantidad de elementos iniciales.

# %%
# print("Before", sensors)

# %% [markdown]
# ### Línea 32
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la impresión del comentario explicativo.

# %% [markdown]
# ### Línea 33
# **Código:** `# #If we wanted to add 3 new rooms, we could use:`
#
# **Explicación técnica:** Comentario explicativo sobre el objetivo de añadir 3 habitaciones adicionales usando el método .update().

# %%
# #If we wanted to add 3 new rooms, we could use:

# %% [markdown]
# ### Línea 34
# **Código:** `# sensors.update({"pantry": 22, "guest room": 25, "patio": 34})`
#
# **Explicación técnica:** Llamada comentada al método .update() con un diccionario nuevo. Demuestra cómo agregar múltiples pares clave-valor en una sola operación.

# %%
# sensors.update({"pantry": 22, "guest room": 25, "patio": 34})

# %% [markdown]
# ### Línea 35
# **Código:** `# print("After", sensors)`
#
# **Explicación técnica:** Instrucción comentada para imprimir 'sensors' modificado. Mostraba el diccionario extendido con las nuevas habitaciones.

# %%
# print("After", sensors)

# %% [markdown]
# ### Línea 36
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la sección de sensores del siguiente ejercicio de IDs.

# %% [markdown]
# ### Línea 37
# **Código:** `###`
#
# **Explicación técnica:** Comentario de separación visual o delimitador de sección.

# %%
###

# %% [markdown]
# ### Línea 38
# **Código:** `# user_ids = {"teraCoder": 9018293, "proProgrammer": 119238}`
#
# **Explicación técnica:** Declara de forma comentada un diccionario 'user_ids' que asocia nombres de usuario con IDs numéricos. Establece los datos iniciales de usuarios.

# %%
# user_ids = {"teraCoder": 9018293, "proProgrammer": 119238}

# %% [markdown]
# ### Línea 39
# **Código:** `# print(user_ids)`
#
# **Explicación técnica:** Instrucción comentada para imprimir los identificadores de usuario iniciales.

# %%
# print(user_ids)

# %% [markdown]
# ### Línea 40
# **Código:** `# user_ids.update({"theLooper": 138475, "stringQueen": 85739})`
#
# **Explicación técnica:** Llamada comentada a .update() para agregar dos nuevos usuarios. Aplica la adición múltiple en una base de datos de usuarios.

# %%
# user_ids.update({"theLooper": 138475, "stringQueen": 85739})

# %% [markdown]
# ### Línea 41
# **Código:** `# print(user_ids)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el registro de usuarios actualizado.

# %%
# print(user_ids)

# %% [markdown]
# ### Línea 42
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el ejercicio previo del bloque de sobreescritura de valores.

# %% [markdown]
# ### Línea 43
# **Código:** `## Overwrite Values ##`
#
# **Explicación técnica:** Comentario de encabezado. Indica el inicio de la explicación sobre sobreescritura de valores existentes.

# %%
## Overwrite Values ##

# %% [markdown]
# ### Línea 44
# **Código:** `#We know that we can add a key by using the following syntax:`
#
# **Explicación técnica:** Comentario explicativo que recuerda la sintaxis mediante corchetes para agregar o modificar claves.

# %%
#We know that we can add a key by using the following syntax:

# %% [markdown]
# ### Línea 45
# **Código:** `#menu["banana"] = 3`
#
# **Explicación técnica:** Ejemplo comentado de asignación directa de valor a una clave ('banana'). Ilustra la sintaxis teórica de actualización.

# %%
#menu["banana"] = 3

# %% [markdown]
# ### Línea 46
# **Código:** `# menu = {"oatmeal": 3, "avocado toast": 6, "carrot juice": 5, "blueberry muffin": 2}`
#
# **Explicación técnica:** Declara de forma comentada el diccionario 'menu' con sus precios base. Prepara la estructura para modificar el precio de 'oatmeal'.

# %%
# menu = {"oatmeal": 3, "avocado toast": 6, "carrot juice": 5, "blueberry muffin": 2}

# %% [markdown]
# ### Línea 47
# **Código:** `# print("Before: ", menu)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el menú en su estado inicial.

# %%
# print("Before: ", menu)

# %% [markdown]
# ### Línea 48
# **Código:** `# menu["oatmeal"] = 5`
#
# **Explicación técnica:** Asignación comentada que cambia el valor de 'oatmeal' de 3 a 5. Demuestra que al asignar sobre una clave existente se actualiza su valor en lugar de duplicarla.

# %%
# menu["oatmeal"] = 5

# %% [markdown]
# ### Línea 49
# **Código:** `# print("After", menu)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el menú con el precio de 'oatmeal' modificado.

# %%
# print("After", menu)

# %% [markdown]
# ### Línea 50
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el ejemplo del menú del caso de los premios Oscar.

# %% [markdown]
# ### Línea 51
# **Código:** `## Notice the value of "oatmeal" has now changed to 5.`
#
# **Explicación técnica:** Comentario aclaratorio que resalta cómo cambió el valor de 'oatmeal' a 5 tras la asignación.

# %%
## Notice the value of "oatmeal" has now changed to 5.

# %% [markdown]
# ### Línea 52
# **Código:** `# oscar_winners = {"Best Picture": "La La Land", "Best Actor": "Casey Affleck", "Best Actress": "Emma Stone", "Animated Feature": "Zootopia"}`
#
# **Explicación técnica:** Declara de forma comentada el diccionario 'oscar_winners' con categorías y ganadores iniciales. Muestra datos reales que requieren corrección.

# %%
# oscar_winners = {"Best Picture": "La La Land", "Best Actor": "Casey Affleck", "Best Actress": "Emma Stone", "Animated Feature": "Zootopia"}

# %% [markdown]
# ### Línea 53
# **Código:** `# print("Before", oscar_winners)`
#
# **Explicación técnica:** Instrucción comentada para imprimir los ganadores de los Oscar antes de las correcciones.

# %%
# print("Before", oscar_winners)

# %% [markdown]
# ### Línea 54
# **Código:** `# print()`
#
# **Explicación técnica:** Instrucción comentada para imprimir una línea en blanco en consola. Se usaba para dar formato a la salida.

# %%
# print()

# %% [markdown]
# ### Línea 55
# **Código:** `# oscar_winners.update({"Supporting Actress": "Viola Davis"})`
#
# **Explicación técnica:** Llamada comentada a .update() para incorporar la categoría 'Supporting Actress'. Agrega un nuevo premio a la lista.

# %%
# oscar_winners.update({"Supporting Actress": "Viola Davis"})

# %% [markdown]
# ### Línea 56
# **Código:** `# print("After1", oscar_winners)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el diccionario tras la primera actualización.

# %%
# print("After1", oscar_winners)

# %% [markdown]
# ### Línea 57
# **Código:** `# print()`
#
# **Explicación técnica:** Instrucción comentada para imprimir un salto de línea adicional.

# %%
# print()

# %% [markdown]
# ### Línea 58
# **Código:** `# oscar_winners["Best Picture"] = "Moonlight"`
#
# **Explicación técnica:** Asignación comentada que cambia el valor de 'Best Picture' a 'Moonlight'. Corrige un dato existente demostrando la modificación directa.

# %%
# oscar_winners["Best Picture"] = "Moonlight"

# %% [markdown]
# ### Línea 59
# **Código:** `# print("After2", oscar_winners)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el estado final del diccionario con el ganador de 'Best Picture' corregido.

# %%
# print("After2", oscar_winners)

# %% [markdown]
# ### Línea 60
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa los módulos de actualización del módulo de comprensión.

# %% [markdown]
# ### Línea 61
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Espaciado adicional.

# %% [markdown]
# ### Línea 62
# **Código:** `###Dict Comprehensions`
#
# **Explicación técnica:** Comentario de encabezado. Introduce la sección dedicada a la creación de diccionarios con comprensión de diccionarios.

# %%
###Dict Comprehensions

# %% [markdown]
# ### Línea 63
# **Código:** `#Let’s say we have two lists that we want to combine into a `
#
# **Explicación técnica:** Comentario explicativo (parte 1 de 3) introduciendo el caso de combinar dos listas independientes.

# %%
#Let’s say we have two lists that we want to combine into a

# %% [markdown]
# ### Línea 64
# **Código:** `#dictionary, like a list of students and a list of their heights, `
#
# **Explicación técnica:** Comentario explicativo (parte 2 de 3) detallando el ejemplo de estudiantes y alturas en pulgadas.

# %%
#dictionary, like a list of students and a list of their heights,

# %% [markdown]
# ### Línea 65
# **Código:** `#in inches:`
#
# **Explicación técnica:** Comentario explicativo (parte 3 de 3) concluyendo la introducción conceptual al ejemplo.

# %%
#in inches:

# %% [markdown]
# ### Línea 66
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la introducción teórica de las declaraciones de variables ejecutables.

# %% [markdown]
# ### Línea 67
# **Código:** `names = ['Jenny', 'Alexus', 'Sam', 'Grace']`
#
# **Explicación técnica:** Declara la lista 'names' con 4 nombres de estudiantes (str). Es la primera lista ejecutable que aportará las claves.

# %%
names = ['Jenny', 'Alexus', 'Sam', 'Grace']

# %% [markdown]
# ### Línea 68
# **Código:** `heights = [61, 70, 67, 64]`
#
# **Explicación técnica:** Declara la lista 'heights' con 4 valores enteros (int). Es la segunda lista ejecutable que aportará los valores de altura.

# %%
heights = [61, 70, 67, 64]

# %% [markdown]
# ### Línea 69
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa las listas de las explicaciones de sintaxis.

# %% [markdown]
# ### Línea 70
# **Código:** `#Python allows you to create a dictionary using `
#
# **Explicación técnica:** Comentario explicativo (parte 1 de 2) indicando que Python permite crear diccionarios con dict comprehensions.

# %%
#Python allows you to create a dictionary using

# %% [markdown]
# ### Línea 71
# **Código:** `# a dict comprehension, with this syntax:`
#
# **Explicación técnica:** Comentario explicativo (parte 2 de 2) señalando la sintaxis del proceso.

# %%
# a dict comprehension, with this syntax:

# %% [markdown]
# ### Línea 72
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el comentario explicativo del código comentado de zip.

# %% [markdown]
# ### Línea 73
# **Código:** `# zipStudents = zip(names, heights)`
#
# **Explicación técnica:** Llamada comentada a zip(names, heights). Ilustra cómo la función zip combina dos listas en pares ordenados de tuplas.

# %%
# zipStudents = zip(names, heights)

# %% [markdown]
# ### Línea 74
# **Código:** `# print("zipStudents: ", zipStudents)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el objeto zip. Muestra que zip devuelve un iterador y no una lista directamente visible.

# %%
# print("zipStudents: ", zipStudents)

# %% [markdown]
# ### Línea 75
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la prueba de zip de la comprensión de diccionarios.

# %% [markdown]
# ### Línea 76
# **Código:** `# students = {key:value for key, value in zip(names, heights)}`
#
# **Explicación técnica:** Estructura comentada de comprensión de diccionario. Muestra cómo transformar los pares de zip directamente en un diccionario.

# %%
# students = {key:value for key, value in zip(names, heights)}

# %% [markdown]
# ### Línea 77
# **Código:** `# #students is now {'Jenny': 61, 'Alexus': 70, 'Sam': 67, 'Grace': 64}`
#
# **Explicación técnica:** Comentario que muestra el resultado esperado dentro de la variable 'students' tras ejecutar la comprensión.

# %%
# #students is now {'Jenny': 61, 'Alexus': 70, 'Sam': 67, 'Grace': 64}

# %% [markdown]
# ### Línea 78
# **Código:** `# print(students)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el diccionario 'students' generado dinámicamente.

# %%
# print(students)

# %% [markdown]
# ### Línea 79
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el ejemplo previo del siguiente caso práctico de bebidas.

# %% [markdown]
# ### Línea 80
# **Código:** `# #zip() combines two lists into an iterator of tuples with the list elements paired together. This dict comprehension:`
#
# **Explicación técnica:** Comentario explicativo que resume cómo funciona zip() al emparejar listas paralelas.

# %%
# #zip() combines two lists into an iterator of tuples with the list elements paired together. This dict comprehension:

# %% [markdown]
# ### Línea 81
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Espaciado previo a las listas de bebidas.

# %% [markdown]
# ### Línea 82
# **Código:** `# drinks = ["espresso", "chai", "decaf", "drip"]`
#
# **Explicación técnica:** Declara de forma comentada una lista de nombres de bebidas (str) para servir como claves.

# %%
# drinks = ["espresso", "chai", "decaf", "drip"]

# %% [markdown]
# ### Línea 83
# **Código:** `# caffeine = [64, 40, 0, 120]`
#
# **Explicación técnica:** Declara de forma comentada una lista de mg de cafeína (int) para servir como valores.

# %%
# caffeine = [64, 40, 0, 120]

# %% [markdown]
# ### Línea 84
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa las listas del emparejamiento zip.

# %% [markdown]
# ### Línea 85
# **Código:** `# zipped_drinks = zip(drinks, caffeine)`
#
# **Explicación técnica:** Empareja de forma comentada las listas de bebidas y cafeína mediante la función zip().

# %%
# zipped_drinks = zip(drinks, caffeine)

# %% [markdown]
# ### Línea 86
# **Código:** `# print(zipped_drinks)`
#
# **Explicación técnica:** Instrucción comentada para imprimir la referencia del objeto zip generado.

# %%
# print(zipped_drinks)

# %% [markdown]
# ### Línea 87
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el zip de la asignación del diccionario.

# %% [markdown]
# ### Línea 88
# **Código:** `# drinks_to_caffeine = {key:value for key, value in zipped_drinks}`
#
# **Explicación técnica:** Construye de forma comentada el diccionario 'drinks_to_caffeine' iterando las tuplas de 'zipped_drinks'.

# %%
# drinks_to_caffeine = {key:value for key, value in zipped_drinks}

# %% [markdown]
# ### Línea 89
# **Código:** `# print(drinks_to_caffeine)`
#
# **Explicación técnica:** Instrucción comentada para imprimir el diccionario de cafeína completado.

# %%
# print(drinks_to_caffeine)

# %% [markdown]
# ### Línea 90
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el ejemplo comentado del bloque ejecutable final.

# %% [markdown]
# ### Línea 91
# **Código:** `songs = ["Like a Rolling Stone", "Satisfaction", "Imagine", "What's Going On", "Respect", "Good Vibrations"]`
#
# **Explicación técnica:** Declara la lista ejecutable 'songs' con 6 títulos de canciones. Establece las claves primarias para el registro de reproducciones.

# %%
songs = ["Like a Rolling Stone", "Satisfaction", "Imagine", "What's Going On", "Respect", "Good Vibrations"]

# %% [markdown]
# ### Línea 92
# **Código:** `playcounts = [78, 29, 44, 21, 89, 5]`
#
# **Explicación técnica:** Declara la lista ejecutable 'playcounts' con 6 números enteros. Define los valores de reproducciones correspondientes.

# %%
playcounts = [78, 29, 44, 21, 89, 5]

# %% [markdown]
# ### Línea 93
# **Código:** `plays = {key:value for key, value in zip(songs, playcounts)}`
#
# **Explicación técnica:** Construye ejecutablemente el diccionario 'plays' emparejando 'songs' y 'playcounts' mediante comprensión y zip().

# %%
plays = {key:value for key, value in zip(songs, playcounts)}

# %% [markdown]
# ### Línea 94
# **Código:** `print(plays)`
#
# **Explicación técnica:** Imprime en consola el diccionario 'plays' recién generado para mostrar el resultado inicial.

# %%
print(plays)

# %% [markdown]
# ### Línea 95
# **Código:** `plays.update({"Purple Haze": 1})`
#
# **Explicación técnica:** Añade la canción 'Purple Haze' con 1 reproducción ejecutando el método .update(). Modifica el diccionario agregando una nueva entrada.

# %%
plays.update({"Purple Haze": 1})

# %% [markdown]
# ### Línea 96
# **Código:** `plays.update({"Respect": 94})`
#
# **Explicación técnica:** Actualiza las reproducciones de 'Respect' a 94 ejecutando el método .update(). Modifica un valor existente en el diccionario.

# %%
plays.update({"Respect": 94})

# %% [markdown]
# ### Línea 97
# **Código:** `print("After: ", plays)`
#
# **Explicación técnica:** Imprime en consola el estado final de 'plays' tras incorporar la nueva canción y actualizar la existente.

# %%
print("After: ", plays)

# %% [markdown]
# ### Línea 98
# **Código:** `library = {"The Best Songs": plays, "Sunday Feelings": {}}`
#
# **Explicación técnica:** Declara el diccionario ejecutable 'library' que contiene a 'plays' en la clave 'The Best Songs' y un diccionario vacío en 'Sunday Feelings'. Crea una estructura anidada.

# %%
library = {"The Best Songs": plays, "Sunday Feelings": {}}

# %% [markdown]
# ### Línea 99
# **Código:** `print(library)`
#
# **Explicación técnica:** Imprime en consola el diccionario completo 'library' mostrando la composición jerárquica final.

# %%
print(library)
