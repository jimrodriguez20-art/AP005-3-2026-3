# %% [markdown]
# # Guía Completa de Operaciones con Diccionarios en Python
# Explicación técnica detallada línea por línea de todo el código (incluyendo comentarios, instrucciones comentadas, encabezados y saltos de línea) preservando intacta la estructura original.

# %% [markdown]
# ### Línea 1
# **Código:** `# #### Get A Key`
#
# **Explicación técnica:** Comentario de encabezado principal. Indica el inicio de la sección dedicada al acceso a valores mediante claves en diccionarios.

# %%
# #### Get A Key

# %% [markdown]
# ### Línea 2
# **Código:** `# #you can access the values in it by providing the key:`
#
# **Explicación técnica:** Comentario explicativo que describe la regla conceptual para consultar elementos proporcionando el nombre de su clave.

# %%
# #you can access the values in it by providing the key:

# %% [markdown]
# ### Línea 3
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa los comentarios de encabezado de las declaraciones de variables.

# %% [markdown]
# ### Línea 4
# **Código:** `# building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}`
#
# **Explicación técnica:** Declara de forma comentada el diccionario 'building_heights' que asocia nombres de rascacielos con sus alturas numéricas en metros.

# %%
# building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}

# %% [markdown]
# ### Línea 5
# **Código:** `# print(building_heights["Burj Khalifa"]) # Prints 828`
#
# **Explicación técnica:** Acceso directo mediante corchetes a la clave 'Burj Khalifa'. Muestra en pantalla el valor 828 asociado a dicha clave.

# %%
# print(building_heights["Burj Khalifa"]) # Prints 828

# %% [markdown]
# ### Línea 6
# **Código:** `# print(building_heights["Ping An"]) # Prints 599`
#
# **Explicación técnica:** Acceso directo mediante corchetes a la clave 'Ping An'. Imprime el valor 599 en consola.

# %%
# print(building_heights["Ping An"]) # Prints 599

# %% [markdown]
# ### Línea 7
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el ejemplo de rascacielos del ejemplo de elementos del zodiaco.

# %% [markdown]
# ### Línea 8
# **Código:** `# zodiac_elements = {"water": ["Cancer", "Scorpio", "Pisces"], "fire": ["Aries", "Leo", "Sagittarius"], "earth": ["Taurus", "Virgo", "Capricorn"], "air":["Gemini", "Libra", "Aquarius"]}`
#
# **Explicación técnica:** Declara de forma comentada el diccionario 'zodiac_elements' mapeando elementos del zodiaco a listas de signos astrológicos.

# %%
# zodiac_elements = {"water": ["Cancer", "Scorpio", "Pisces"], "fire": ["Aries", "Leo", "Sagittarius"], "earth": ["Taurus", "Virgo", "Capricorn"], "air":["Gemini", "Libra", "Aquarius"]}

# %% [markdown]
# ### Línea 9
# **Código:** `# print(zodiac_elements["earth"])`
#
# **Explicación técnica:** Accede a la clave 'earth' mediante corchetes e imprime su valor asociado (la lista de signos de tierra).

# %%
# print(zodiac_elements["earth"])

# %% [markdown]
# ### Línea 10
# **Código:** `# print(zodiac_elements["fire"])`
#
# **Explicación técnica:** Accede a la clave 'fire' e imprime la lista de signos de fuego.

# %%
# print(zodiac_elements["fire"])

# %% [markdown]
# ### Línea 11
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la sección previa del bloque de claves inválidas.

# %% [markdown]
# ### Línea 12
# **Código:** `# ## Get an Invalid Key`
#
# **Explicación técnica:** Comentario de subencabezado. Introduce el caso de error al intentar acceder a una clave inexistente en un diccionario.

# %%
# ## Get an Invalid Key

# %% [markdown]
# ### Línea 13
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Espaciado estructural.

# %% [markdown]
# ### Línea 14
# **Código:** `# building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}`
#
# **Explicación técnica:** Re-declara de forma comentada el diccionario 'building_heights' para realizar la prueba de acceso erróneo.

# %%
# building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}

# %% [markdown]
# ### Línea 15
# **Código:** `# print(building_heights["Landmark 81"])`
#
# **Explicación técnica:** Intento comentado de acceder a 'Landmark 81', una clave no existente en el diccionario. Lanza un error de tipo KeyError.

# %%
# print(building_heights["Landmark 81"])

# %% [markdown]
# ### Línea 16
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la demostración del error de su técnica de prevención.

# %% [markdown]
# ### Línea 17
# **Código:** `# ##One way to avoid this error is to first check if the key exists in the dictionary:`
#
# **Explicación técnica:** Comentario explicativo que propone utilizar el operador de pertenencia 'in' para validar la existencia de una clave antes de consultar.

# %%
# ##One way to avoid this error is to first check if the key exists in the dictionary:

# %% [markdown]
# ### Línea 18
# **Código:** `# key_to_check = "Landmark 81"`
#
# **Explicación técnica:** Declara la variable 'key_to_check' asignándole la cadena 'Landmark 81' para usarla en la validación condicional.

# %%
# key_to_check = "Landmark 81"

# %% [markdown]
# ### Línea 19
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la variable de la estructura condicional.

# %% [markdown]
# ### Línea 20
# **Código:** `# if key_to_check in building_heights:`
#
# **Explicación técnica:** Estructura condicional 'if' que verifica si el valor de 'key_to_check' está presente como clave en 'building_heights'.

# %%
# if key_to_check in building_heights:

# %% [markdown]
# ### Línea 21
# **Código:** `#    print(building_heights["Landmark 81"])`
#
# **Explicación técnica:** Instrucción comentada dentro del condicional. Solo se ejecutaría si la clave existiera, evitando que el programa colapse por KeyError.

# %%
#    print(building_heights["Landmark 81"])

# %% [markdown]
# ### Línea 22
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el condicional previo del nuevo ejemplo del zodiaco.

# %% [markdown]
# ### Línea 23
# **Código:** `# zodiac_elements = {"water": ["Cancer", "Scorpio", "Pisces"], "fire": ["Aries", "Leo", "Sagittarius"], "earth": ["Taurus", "Virgo", "Capricorn"], "air":["Gemini", "Libra", "Aquarius"]}`
#
# **Explicación técnica:** Re-declara el diccionario 'zodiac_elements' para aplicar la validación de presencia con 'in'.

# %%
# zodiac_elements = {"water": ["Cancer", "Scorpio", "Pisces"], "fire": ["Aries", "Leo", "Sagittarius"], "earth": ["Taurus", "Virgo", "Capricorn"], "air":["Gemini", "Libra", "Aquarius"]}

# %% [markdown]
# ### Línea 24
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Espaciado funcional.

# %% [markdown]
# ### Línea 25
# **Código:** `# zodiac_elements["energy"] = "Not a Zodiac element"`
#
# **Explicación técnica:** Agrega una nueva clave 'energy' con el texto 'Not a Zodiac element' al diccionario 'zodiac_elements' mediante asignación directa.

# %%
# zodiac_elements["energy"] = "Not a Zodiac element"

# %% [markdown]
# ### Línea 26
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la asignación del condicional de verificación.

# %% [markdown]
# ### Línea 27
# **Código:** `# if "energy" in zodiac_elements:`
#
# **Explicación técnica:** Evalúa condicionalmente si la cadena 'energy' existe entre las claves de 'zodiac_elements'.

# %%
# if "energy" in zodiac_elements:

# %% [markdown]
# ### Línea 28
# **Código:** `#    print(zodiac_elements["energy"])`
#
# **Explicación técnica:** Imprime el valor de la clave 'energy' al confirmarse su existencia en la estructura.

# %%
#    print(zodiac_elements["energy"])

# %% [markdown]
# ### Línea 29
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el bloque condicional de la siguiente sección.

# %% [markdown]
# ### Línea 30
# **Código:** `# ##Safely Get a Key`
#
# **Explicación técnica:** Comentario de subencabezado. Introduce el método seguro .get() para consultar claves sin arriesgar un error de ejecución.

# %%
# ##Safely Get a Key

# %% [markdown]
# ### Línea 31
# **Código:** `# building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}`
#
# **Explicación técnica:** Re-declaración comentada de 'building_heights' como conjunto de datos para las pruebas con .get().

# %%
# building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}

# %% [markdown]
# ### Línea 32
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Espaciado previo al ejemplo de clave válida.

# %% [markdown]
# ### Línea 33
# **Código:** `# #this line will return 632:`
#
# **Explicación técnica:** Comentario aclaratorio indicando que la siguiente consulta devolverá el valor numérico 632.

# %%
# #this line will return 632:

# %% [markdown]
# ### Línea 34
# **Código:** `# building_heights.get("Shanghai Tower")`
#
# **Explicación técnica:** Llamada al método .get('Shanghai Tower'). Retorna 632 de forma segura al existir la clave.

# %%
# building_heights.get("Shanghai Tower")

# %% [markdown]
# ### Línea 35
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el ejemplo positivo del ejemplo con clave inexistente.

# %% [markdown]
# ### Línea 36
# **Código:** `# #this line will return None:`
#
# **Explicación técnica:** Comentario aclaratorio indicando que al buscar una clave inexistente con .get() se devuelve None en lugar de lanzar un error.

# %%
# #this line will return None:

# %% [markdown]
# ### Línea 37
# **Código:** `# building_heights.get("My House")`
#
# **Explicación técnica:** Llamada al método .get('My House'). Al no existir la clave, retorna None en lugar de detener la ejecución.

# %%
# building_heights.get("My House")

# %% [markdown]
# ### Línea 38
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la demostración conceptual del siguiente ejercicio práctico.

# %% [markdown]
# ### Línea 39
# **Código:** `###`
#
# **Explicación técnica:** Comentario de delimitación o separación visual de bloques de código.

# %%
###

# %% [markdown]
# ### Línea 40
# **Código:** `# user_ids = {"teraCoder": 100019, "pythonGuy": 182921, "samTheJavaMaam": 123112, "lyleLoop": 102931, "keysmithKeith": 129384}`
#
# **Explicación técnica:** Declara el diccionario 'user_ids' relacionando nombres de usuario con sus IDs numéricos.

# %%
# user_ids = {"teraCoder": 100019, "pythonGuy": 182921, "samTheJavaMaam": 123112, "lyleLoop": 102931, "keysmithKeith": 129384}

# %% [markdown]
# ### Línea 41
# **Código:** `# user_ids.get("teraCoder")`
#
# **Explicación técnica:** Consulta la clave 'teraCoder' usando el método seguro .get(), devolviendo 100019.

# %%
# user_ids.get("teraCoder")

# %% [markdown]
# ### Línea 42
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la consulta simple de la lógica de asignación condicional.

# %% [markdown]
# ### Línea 43
# **Código:** `# if user_ids.get("teraCoder") == None:`
#
# **Explicación técnica:** Evalúa si la búsqueda de la clave 'teraCoder' devuelve None (es decir, si la clave no existe).

# %%
# if user_ids.get("teraCoder") == None:

# %% [markdown]
# ### Línea 44
# **Código:** `#    tc_id = 1000`
#
# **Explicación técnica:** Asigna un valor predeterminado de 1000 a 'tc_id' en caso de que la clave no exista.

# %%
#    tc_id = 1000

# %% [markdown]
# ### Línea 45
# **Código:** `# else:`
#
# **Explicación técnica:** Rama alternativa del condicional si la clave sí existe.

# %%
# else:

# %% [markdown]
# ### Línea 46
# **Código:** `#    tc_id = user_ids.get("teraCoder")`
#
# **Explicación técnica:** Asigna a 'tc_id' el valor real obtenido del diccionario para la clave 'teraCoder'.

# %%
#    tc_id = user_ids.get("teraCoder")

# %% [markdown]
# ### Línea 47
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la lógica de asignación de la impresión del resultado.

# %% [markdown]
# ### Línea 48
# **Código:** `# print(tc_id)`
#
# **Explicación técnica:** Imprime el valor resultante asignado a la variable 'tc_id' (100019).

# %%
# print(tc_id)

# %% [markdown]
# ### Línea 49
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la prueba anterior de una nueva evaluación con clave inexistente.

# %% [markdown]
# ### Línea 50
# **Código:** `# if user_ids.get("superStackSmash") == None:`
#
# **Explicación técnica:** Evalúa si la clave 'superStackSmash' no existe en el diccionario (retorna None).

# %%
# if user_ids.get("superStackSmash") == None:

# %% [markdown]
# ### Línea 51
# **Código:** `#      stack_id = 100000`
#
# **Explicación técnica:** Asigna el valor por defecto 100000 a la variable 'stack_id' al no encontrarse el usuario.

# %%
#      stack_id = 100000

# %% [markdown]
# ### Línea 52
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la asignación de la salida por consola.

# %% [markdown]
# ### Línea 53
# **Código:** `# print(stack_id)`
#
# **Explicación técnica:** Imprime en consola el valor almacenado en 'stack_id' (100000).

# %%
# print(stack_id)

# %% [markdown]
# ### Línea 54
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el bloque de usuarios de la sección de eliminación.

# %% [markdown]
# ### Línea 55
# **Código:** `# ###Delete a Key`
#
# **Explicación técnica:** Comentario de encabezado principal. Introduce el tema de eliminación de claves y valores de un diccionario.

# %%
# ###Delete a Key

# %% [markdown]
# ### Línea 56
# **Código:** `# .pop() works to delete items from a dictionary, when you know the key value.`
#
# **Explicación técnica:** Comentario explicativo que detalla cómo funciona el método .pop() para extraer y eliminar elementos conociendo su clave.

# %%
# .pop() works to delete items from a dictionary, when you know the key value.

# %% [markdown]
# ### Línea 57
# **Código:** `# raffle = {223842: "Teddy Bear", 872921: "Concert Tickets", 320291: "Gift Basket", 412123: "Necklace", 298787: "Pasta Maker"}`
#
# **Explicación técnica:** Declara de forma comentada el diccionario 'raffle' (rifa) relacionando números de boleto con sus premios asociados.

# %%
# raffle = {223842: "Teddy Bear", 872921: "Concert Tickets", 320291: "Gift Basket", 412123: "Necklace", 298787: "Pasta Maker"}

# %% [markdown]
# ### Línea 58
# **Código:** `# print(raffle.pop(320291, "No Prize"))`
#
# **Explicación técnica:** Elimina la clave 320291 mediante .pop() e imprime su valor extraído ('Gift Basket'). Retornaría 'No Prize' si no existiera.

# %%
# print(raffle.pop(320291, "No Prize"))

# %% [markdown]
# ### Línea 59
# **Código:** `# ## Prints "Gift Basket"`
#
# **Explicación técnica:** Comentario indicativo de la salida esperada por consola.

# %%
# ## Prints "Gift Basket"

# %% [markdown]
# ### Línea 60
# **Código:** `# print(raffle)`
#
# **Explicación técnica:** Imprime el diccionario 'raffle' tras haber eliminado el boleto 320291.

# %%
# print(raffle)

# %% [markdown]
# ### Línea 61
# **Código:** `# # Prints {223842: "Teddy Bear", 872921: "Concert Tickets", 412123: "Necklace", 298787: "Pasta Maker"}`
#
# **Explicación técnica:** Comentario que muestra el estado resultante del diccionario tras la extracción previa.

# %%
# # Prints {223842: "Teddy Bear", 872921: "Concert Tickets", 412123: "Necklace", 298787: "Pasta Maker"}

# %% [markdown]
# ### Línea 62
# **Código:** `# print(raffle.pop(100000, "No Prize"))`
#
# **Explicación técnica:** Intenta eliminar la clave inexistente 100000 con .pop(). Al no existir, retorna e imprime el valor por defecto 'No Prize' sin lanzar error.

# %%
# print(raffle.pop(100000, "No Prize"))

# %% [markdown]
# ### Línea 63
# **Código:** `# # Prints "No Prize"`
#
# **Explicación técnica:** Comentario indicativo del resultado impreso en pantalla.

# %%
# # Prints "No Prize"

# %% [markdown]
# ### Línea 64
# **Código:** `# print(raffle)`
#
# **Explicación técnica:** Imprime el diccionario 'raffle' confirmando que permaneció inalterado al no hallarse la clave 100000.

# %%
# print(raffle)

# %% [markdown]
# ### Línea 65
# **Código:** `# # Prints {223842: "Teddy Bear", 872921: "Concert Tickets", 412123: "Necklace", 298787: "Pasta Maker"}`
#
# **Explicación técnica:** Comentario mostrando que el diccionario conservó todos sus elementos.

# %%
# # Prints {223842: "Teddy Bear", 872921: "Concert Tickets", 412123: "Necklace", 298787: "Pasta Maker"}

# %% [markdown]
# ### Línea 66
# **Código:** `# print(raffle.pop(872921, "No Prize"))`
#
# **Explicación técnica:** Elimina la clave 872921 con .pop() e imprime su valor extraído ('Concert Tickets').

# %%
# print(raffle.pop(872921, "No Prize"))

# %% [markdown]
# ### Línea 67
# **Código:** `# # Prints "Concert Tickets"`
#
# **Explicación técnica:** Comentario indicativo de la salida de la extracción.

# %%
# # Prints "Concert Tickets"

# %% [markdown]
# ### Línea 68
# **Código:** `# print(raffle)`
#
# **Explicación técnica:** Imprime el diccionario 'raffle' reflejando la segunda eliminación de premio.

# %%
# print(raffle)

# %% [markdown]
# ### Línea 69
# **Código:** `# # Prints {223842: "Teddy Bear", 412123: "Necklace", 298787: "Pasta Maker"}`
#
# **Explicación técnica:** Comentario indicando el estado final de 'raffle' con 3 elementos restantes.

# %%
# # Prints {223842: "Teddy Bear", 412123: "Necklace", 298787: "Pasta Maker"}

# %% [markdown]
# ### Línea 70
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el ejemplo de la rifa de un ejercicio práctico en videojuegos.

# %% [markdown]
# ### Línea 71
# **Código:** `# available_items = {"health potion": 10, "cake of the cure": 5, "green elixir": 20, "strength sandwich": 25, "stamina grains": 15, "power stew": 30}`
#
# **Explicación técnica:** Declara el diccionario 'available_items' con ítems consumibles y los puntos de vida que otorgan.

# %%
# available_items = {"health potion": 10, "cake of the cure": 5, "green elixir": 20, "strength sandwich": 25, "stamina grains": 15, "power stew": 30}

# %% [markdown]
# ### Línea 72
# **Código:** `# health_points = 20`
#
# **Explicación técnica:** Declara la variable de estado 'health_points' e inicializa los puntos de vida base en 20.

# %%
# health_points = 20

# %% [markdown]
# ### Línea 73
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la inicialización de las operaciones de consumo.

# %% [markdown]
# ### Línea 74
# **Código:** `# health_points += available_items.pop("stamina grains", 0)`
#
# **Explicación técnica:** Extrae 'stamina grains' del diccionario consumiendo el ítem y suma sus puntos (15) a 'health_points'.

# %%
# health_points += available_items.pop("stamina grains", 0)

# %% [markdown]
# ### Línea 75
# **Código:** `# health_points += available_items.pop("power stew", 0)`
#
# **Explicación técnica:** Extrae 'power stew' consumiéndolo y suma sus puntos (30) a 'health_points'.

# %%
# health_points += available_items.pop("power stew", 0)

# %% [markdown]
# ### Línea 76
# **Código:** `# health_points += available_items.pop("mystic bread", 0)`
#
# **Explicación técnica:** Intenta consumir 'mystic bread'. Al no existir en el inventario, .pop() devuelve el valor por defecto 0 sin alterar la suma.

# %%
# health_points += available_items.pop("mystic bread", 0)

# %% [markdown]
# ### Línea 77
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa las operaciones aritméticas del reporte final.

# %% [markdown]
# ### Línea 78
# **Código:** `# print(available_items)`
#
# **Explicación técnica:** Imprime el inventario restante tras haber consumido los ítems.

# %%
# print(available_items)

# %% [markdown]
# ### Línea 79
# **Código:** `# print(health_points)`
#
# **Explicación técnica:** Imprime el acumulado total de puntos de vida (65).

# %%
# print(health_points)

# %% [markdown]
# ### Línea 80
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el bloque de eliminación de la sección de claves.

# %% [markdown]
# ### Línea 81
# **Código:** `# ##Get All Keys`
#
# **Explicación técnica:** Comentario de encabezado principal. Introduce los métodos para obtener y listar todas las claves de un diccionario.

# %%
# ##Get All Keys

# %% [markdown]
# ### Línea 82
# **Código:** `# test_scores = {"Grace":[80, 72, 90], "Jeffrey":[88, 68, 81], "Sylvia":[80, 82, 84], "Pedro":[98, 96, 95], "Martin":[78, 80, 78], "Dina":[64, 60, 75]}`
#
# **Explicación técnica:** Declara de forma comentada el diccionario 'test_scores' asociando nombres de estudiantes con listas de calificaciones.

# %%
# test_scores = {"Grace":[80, 72, 90], "Jeffrey":[88, 68, 81], "Sylvia":[80, 82, 84], "Pedro":[98, 96, 95], "Martin":[78, 80, 78], "Dina":[64, 60, 75]}

# %% [markdown]
# ### Línea 83
# **Código:** `# print(list(test_scores))`
#
# **Explicación técnica:** Convierte directamente el diccionario a una lista e imprime sus claves. Por defecto, iterar o convertir un diccionario extrae únicamente sus claves.

# %%
# print(list(test_scores))

# %% [markdown]
# ### Línea 84
# **Código:** `# # Prints ["Grace", "Jeffrey", "Sylvia", "Pedro", "Martin", "Dina"]`
#
# **Explicación técnica:** Comentario que muestra la lista de claves resultante.

# %%
# # Prints ["Grace", "Jeffrey", "Sylvia", "Pedro", "Martin", "Dina"]

# %% [markdown]
# ### Línea 85
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la conversión explícita del bucle de iteración.

# %% [markdown]
# ### Línea 86
# **Código:** `# for student in test_scores.keys():`
#
# **Explicación técnica:** Bucle 'for' que itera sobre la vista dict_keys devuelta por el método .keys().

# %%
# for student in test_scores.keys():

# %% [markdown]
# ### Línea 87
# **Código:** `#  print(student)`
#
# **Explicación técnica:** Imprime en cada iteración el nombre del estudiante (la clave).

# %%
#  print(student)

# %% [markdown]
# ### Línea 88
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la iteración del siguiente ejercicio con diccionarios múltiples.

# %% [markdown]
# ### Línea 89
# **Código:** `# user_ids = {"teraCoder": 100019, "pythonGuy": 182921, "samTheJavaMaam": 123112, "lyleLoop": 102931, "keysmithKeith": 129384}`
#
# **Explicación técnica:** Re-declara el diccionario 'user_ids' para extraer sus claves.

# %%
# user_ids = {"teraCoder": 100019, "pythonGuy": 182921, "samTheJavaMaam": 123112, "lyleLoop": 102931, "keysmithKeith": 129384}

# %% [markdown]
# ### Línea 90
# **Código:** `# num_exercises = {"functions": 10, "syntax": 13, "control flow": 15, "loops": 22, "lists": 19, "classes": 18, "dictionaries": 18}`
#
# **Explicación técnica:** Declara el diccionario 'num_exercises' asociando temas de estudio con la cantidad de ejercicios.

# %%
# num_exercises = {"functions": 10, "syntax": 13, "control flow": 15, "loops": 22, "lists": 19, "classes": 18, "dictionaries": 18}

# %% [markdown]
# ### Línea 91
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa los diccionarios de la extracción de vistas.

# %% [markdown]
# ### Línea 92
# **Código:** `# users = user_ids.keys()`
#
# **Explicación técnica:** Obtiene la vista de claves de 'user_ids' mediante .keys() y la asigna a la variable 'users'.

# %%
# users = user_ids.keys()

# %% [markdown]
# ### Línea 93
# **Código:** `# lessons = num_exercises.keys()`
#
# **Explicación técnica:** Obtiene la vista de claves de 'num_exercises' mediante .keys() y la guarda en 'lessons'.

# %%
# lessons = num_exercises.keys()

# %% [markdown]
# ### Línea 94
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la asignación de las impresiones.

# %% [markdown]
# ### Línea 95
# **Código:** `# print(users)`
#
# **Explicación técnica:** Imprime en consola el objeto dict_keys resultante con los nombres de usuario.

# %%
# print(users)

# %% [markdown]
# ### Línea 96
# **Código:** `# print(lessons)`
#
# **Explicación técnica:** Imprime en consola la vista dict_keys con los temas de las lecciones.

# %%
# print(lessons)

# %% [markdown]
# ### Línea 97
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la sección de claves de la sección de valores.

# %% [markdown]
# ### Línea 98
# **Código:** `##Get All Values`
#
# **Explicación técnica:** Comentario de encabezado principal. Introduce la extracción iterativa de todos los valores de un diccionario.

# %%
##Get All Values

# %% [markdown]
# ### Línea 99
# **Código:** `# test_scores = {"Grace":[80, 72, 90], "Jeffrey":[88, 68, 81], "Sylvia":[80, 82, 84], "Pedro":[98, 96, 95], "Martin":[78, 80, 78], "Dina":[64, 60, 75]}`
#
# **Explicación técnica:** Re-declaración comentada de 'test_scores' para analizar la extracción de sus valores.

# %%
# test_scores = {"Grace":[80, 72, 90], "Jeffrey":[88, 68, 81], "Sylvia":[80, 82, 84], "Pedro":[98, 96, 95], "Martin":[78, 80, 78], "Dina":[64, 60, 75]}

# %% [markdown]
# ### Línea 100
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Espaciado funcional.

# %% [markdown]
# ### Línea 101
# **Código:** `# for score_list in test_scores.values():`
#
# **Explicación técnica:** Bucle 'for' que recorre la vista devuelta por .values(), iterando directamente sobre las listas de notas.

# %%
# for score_list in test_scores.values():

# %% [markdown]
# ### Línea 102
# **Código:** `#  print(score_list)`
#
# **Explicación técnica:** Imprime en consola cada lista de calificaciones por iteración.

# %%
#  print(score_list)

# %% [markdown]
# ### Línea 103
# **Código:** `# num_exercises = {"functions": 10, "syntax": 13, "control flow": 15, "loops": 22, "lists": 19, "classes": 18, "dictionaries": 18}`
#
# **Explicación técnica:** Re-declaración de 'num_exercises' para calcular la suma de sus valores.

# %%
# num_exercises = {"functions": 10, "syntax": 13, "control flow": 15, "loops": 22, "lists": 19, "classes": 18, "dictionaries": 18}

# %% [markdown]
# ### Línea 104
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el diccionario del acumulador.

# %% [markdown]
# ### Línea 105
# **Código:** `# total_exercises = 0`
#
# **Explicación técnica:** Inicializa la variable acumuladora 'total_exercises' en 0.

# %%
# total_exercises = 0

# %% [markdown]
# ### Línea 106
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la inicialización del bucle acumulativo.

# %% [markdown]
# ### Línea 107
# **Código:** `# for exercises in num_exercises.values():`
#
# **Explicación técnica:** Itera sobre cada valor numérico entero del diccionario mediante .values().

# %%
# for exercises in num_exercises.values():

# %% [markdown]
# ### Línea 108
# **Código:** `#    total_exercises += exercises`
#
# **Explicación técnica:** Suma e incrementa el número de ejercicios actual en la variable 'total_exercises'.

# %%
#    total_exercises += exercises

# %% [markdown]
# ### Línea 109
# **Código:** `# print(total_exercises)`
#
# **Explicación técnica:** Imprime el total acumulado de ejercicios (115).

# %%
# print(total_exercises)

# %% [markdown]
# ### Línea 110
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa la sección de valores de la sección de items.

# %% [markdown]
# ### Línea 111
# **Código:** `##Get All Items`
#
# **Explicación técnica:** Comentario de encabezado principal. Introduce la iteración simultánea de claves y valores mediante el método .items().

# %%
##Get All Items

# %% [markdown]
# ### Línea 112
# **Código:** `# biggest_brands = {"Apple": 184, "Google": 141.7, "Microsoft": 80, "Coca-Cola": 69.7, "Amazon": 64.8}`
#
# **Explicación técnica:** Declara de forma comentada el diccionario 'biggest_brands' asociando marcas con su valor de mercado en miles de millones de dólares.

# %%
# biggest_brands = {"Apple": 184, "Google": 141.7, "Microsoft": 80, "Coca-Cola": 69.7, "Amazon": 64.8}

# %% [markdown]
# ### Línea 113
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Espaciado previo al bucle de desempaquetado.

# %% [markdown]
# ### Línea 114
# **Código:** `# for company, value in biggest_brands.items():`
#
# **Explicación técnica:** Bucle 'for' que desempaqueta cada tupla (clave, valor) devuelta por .items() en las variables 'company' y 'value'.

# %%
# for company, value in biggest_brands.items():

# %% [markdown]
# ### Línea 115
# **Código:** `#  print(company + " has a value of " + str(value) + " billion dollars. ")`
#
# **Explicación técnica:** Imprime una cadena formateada concatenando la empresa y su valor convertido a texto.

# %%
#  print(company + " has a value of " + str(value) + " billion dollars. ")

# %% [markdown]
# ### Línea 116
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el ejemplo de marcas del siguiente ejercicio sociodemográfico.

# %% [markdown]
# ### Línea 117
# **Código:** `# pct_women_in_occupation = {"CEO": 28, "Engineering Manager": 9, "Pharmacist": 58, "Physician": 40, "Lawyer": 37, "Aerospace Engineer": 9}`
#
# **Explicación técnica:** Declara el diccionario 'pct_women_in_occupation' con ocupaciones y el porcentaje de participación femenina.

# %%
# pct_women_in_occupation = {"CEO": 28, "Engineering Manager": 9, "Pharmacist": 58, "Physician": 40, "Lawyer": 37, "Aerospace Engineer": 9}

# %% [markdown]
# ### Línea 118
# **Código:** `(Línea en blanco)`
#
# **Explicación técnica:** Línea en blanco. Separa el diccionario de la iteración final.

# %% [markdown]
# ### Línea 119
# **Código:** `# for occupation, percentage in pct_women_in_occupation.items():`
#
# **Explicación técnica:** Itera sobre las tuplas (clave, valor) de profesiones y porcentajes utilizando .items().

# %%
# for occupation, percentage in pct_women_in_occupation.items():

# %% [markdown]
# ### Línea 120
# **Código:** `#    print("Women make up " + str(percentage) + " percent of " + occupation + "s.")`
#
# **Explicación técnica:** Imprime la frase estructurada concatenando la profesión y el porcentaje correspondiente por cada iteración.

# %%
#    print("Women make up " + str(percentage) + " percent of " + occupation + "s.")
